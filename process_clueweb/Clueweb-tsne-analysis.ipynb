# %%
import pickle, sys
sys.path.append('../src')
import data_io # eval
import random
import numpy as np
from scipy.stats import spearmanr
from scipy.stats import pearsonr
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.decomposition import TruncatedSVD
import matplotlib.pyplot as plt
import pprint
from scipy.stats import iqr
import time
import random
import itertools
import gzip, cPickle
import matplotlib.pyplot as plt
from tsne import bh_sne
import mpld3
import matplotlib.cm as cm
import matplotlib.patches as mpatches



    
###############################################################################
###                         Helper Classes                                  ###
###############################################################################

class params(object):
    
    def __init__(self):
        self.LW = 1e-5
        self.LC = 1e-5
        self.eta = 0.05

    def __str__(self):
        t = "LW", self.LW, ", LC", self.LC, ", eta", self.eta
        t = map(str, t)
        return ' '.join(t)

## run
### the following is the word embeddings maps to use, download them pretrained
wordfiles = [#'../data/paragram_sl999_small.txt', # need to download it from John Wieting's github (https://github.com/jwieting/iclr2016)
    # '/Users/corbinrosset/Dropbox/GloVe/glove.840B.300d.txt'
    '/Users/corbinrosset/Dropbox/Paragrams/paragrams-XXL-SL999.txt'

    ]
weightfile = '/Users/corbinrosset/Dropbox/Arora/QA-code/src/WordEmdgs/SIF/auxiliary_data/enwiki_vocab_min200.txt'
weightparas = [1e-2] ### used 1e-2 #[-1,1e-1,1e-2,1e-3,1e-4] # (0.01 works best)
# weightparas = [-1,1e-1,1e-2,1e-3,1e-4] # (0.01 works best)

rmpcs = [0] #[0, 1, 2, 3, 4] # remove the first k principle components, (4 is best)
scoring_function = None
save_result = False 

data_dir = '/Users/corbinrosset/Dropbox/Arora/QA-data/VanDurme_FB_annotations/annotated_clueweb/ClueWeb09_English_1/processed/' ### clueweb data
# data_dir = '../data/' ### for textual similarity data
paraphrases_file = 'grouped_textual_triples.pkl' ### for clueweb data
# paraphrases_file = 'combined_test_data_normed' ### for textual similarity data

data = data_dir + paraphrases_file

farr = ["MSRpar2012_normed",            # good
        "OnWN2012_normed",             # good
        "SMTeuro2012_normed",          # good 
        "SMTnews2012_normed",          # good
        "FNWN2013_normed",             # good
        "OnWN2013_normed",             # good
        "headlines2013_normed",        # good
        "OnWN2014_normed",             # good
        "deft-forum2014_normed",       # good
        "deft-news2014_normed",        # good
        "headlines2014_normed",        # good
        "images2014_normed",           # good
        "tweet-news2014_normed", # 14  # good
        "answers-forum2015_normed",    # good
        "answers-student2015_normed",  # good
        "belief2015_normed",           # good
        "headlines2015_normed",        # good
        "images2015_normed",    # 19   # good
        "sicktest_normed",             # good
        "annotated-ppdb-dev_normed",   # good
        "annotated-ppdb-test_normed"]  # good


execute_path = '/Users/corbinrosset/Dropbox/Arora/QA-code/'
params = params()
parr4para = {}
sarr4para = {}
wordfile = wordfiles[0]
# Out:
# Couldn't import dot_parser, loading of dot files will not be possible.

# %%
### load word embeddings map
print 'loading word embeddings map...will take many minutes'
start = time.clock() 
(words, We) = data_io.getWordmap(wordfile)
elapsed = time.clock()
elapsed = elapsed - start
print 'word vectors loaded from %s' % wordfile
print "loaded word vectors in: ", elapsed
# Out:
# loading word embeddings map...will take many minutes
# loaded word vectors in:  586.708738
# word vectors loaded from /Users/corbinrosset/Dropbox/Paragrams/paragrams-XXL-SL999.txt

# %%
### load data
print 'loading data'
start = time.clock() 
DATA = pickle.load(open(data, 'r'))
elapsed = time.clock()
elapsed = elapsed - start
print "loaded ", str(data), " data in: ", elapsed
# Out:
# loading data
# loaded  /Users/corbinrosset/Dropbox/Arora/QA-data/VanDurme_FB_annotations/annotated_clueweb/ClueWeb09_English_1/processed/grouped_textual_triples.pkl  data in:  88.377085

# %%
###############################################################################
###            Helper Methods for the Original Textual Similarity Task      ###
###############################################################################

def evaluate_similarity(We,words,f, weight4ind, scoring_function, params):
    golds = []
    seq1 = []
    seq2 = []
    with open(f,'r') as fl:
        for i in fl:
            i = i.split("\t")
            p1 = i[0]; p2 = i[1]; score = float(i[2])
            X1, X2 = data_io.getSeqs(p1,p2,words)
            seq1.append(X1)
            seq2.append(X2)
            golds.append(score)
    x1,m1 = data_io.prepare_data(seq1)
    x2,m2 = data_io.prepare_data(seq2)
    m1 = data_io.seq2weight(x1, m1, weight4ind)
    m2 = data_io.seq2weight(x2, m2, weight4ind)
    scores = scoring_function(We,x1,x2,m1,m2, params)
    preds = np.squeeze(scores)
    return pearsonr(preds,golds)[0], spearmanr(preds,golds)[0]

def get_embeddings(We, words, data, weight4ind, params):

    ### asssuming data is the similarity dataset:
    seq, labels, sentences = [], [], []
    with open(data,'r') as fl:
        for idx, i in enumerate(fl):
            i = i.split("\t")
            p1 = i[0]; p2 = i[1]; score = float(i[2])
            X1, X2 = data_io.getSeqs(p1,p2,words)
            seq.append(X1)
            seq.append(X2)
            labels.append(score)
            labels.append(score)
            sentences.append(p1)
            sentences.append(p2)

    x1, w1 = data_io.prepare_data(seq)
    emb, embnorm = get_norm_embedding(We, x1, w1, params)
    emb = np.asarray(emb, dtype=np.float64)
    # perhaps divide each row by its L2 norm, emb /= embnorm
    print np.shape(emb)
    return emb, labels, sentences




###############################################################################
###                      SIF Averaging Methods                              ###
###############################################################################

def get_weighted_average(We, x, w):
    """
    Compute the weighted average vectors
    :param We: We[i,:] is the vector for word i
    :param x: x[i, :] are the indices of the words in sentence i
    :param w: w[i, :] are the weights for the words in sentence i
    :return: emb[i, :] are the weighted average vector for sentence i
    """
    n_samples = x.shape[0]
    emb = np.zeros((n_samples, We.shape[1]))
    for i in xrange(n_samples):
        emb[i,:] = w[i,:].dot(We[x[i,:],:]) / np.count_nonzero(w[i,:])
    return emb

def compute_pc(X,npc=1):
    """
    Compute the principal components
    :param X: X[i,:] is a data point
    :param npc: number of principal components to remove
    :return: component_[i,:] is the i-th pc
    """
    svd = TruncatedSVD(n_components=npc, n_iter=7, random_state=0)
    svd.fit(X)
    return svd.components_

def remove_pc(X, npc=1):
    """
    Remove the projection on the principal components
    :param X: X[i,:] is a data point
    :param npc: number of principal components to remove
    :return: XX[i, :] is the data point after removing its projection
    """
    pc = compute_pc(X, npc)
    if npc==1:
        XX = X - X.dot(pc.transpose()) * pc
    else:
        XX = X - X.dot(pc.transpose()).dot(pc)
    return XX

def get_norm_embedding(We, x1, w1, params):
    '''basically does what the scoring function below does, but for one sentence'''
    emb1 = get_weighted_average(We, x1, w1) # num samples by embedding dim
    if  params.rmpc > 0:
        emb1 = remove_pc(emb1, params.rmpc)
    emb1norm = np.sqrt((emb1 * emb1).sum(axis=1))
    return emb1, emb1norm

def weighted_average_sim_rmpc(We,x1,x2,w1,w2, params):
    """
    Compute the scores between pairs of sentences using weighted average + removing the projection on the first principal component
    :param We: We[i,:] is the vector for word i
    :param x1: x1[i, :] are the indices of the words in the first sentence in pair i
    :param x2: x2[i, :] are the indices of the words in the second sentence in pair i
    :param w1: w1[i, :] are the weights for the words in the first sentence in pair i
    :param w2: w2[i, :] are the weights for the words in the first sentence in pair i
    :param params.rmpc: if >0, remove the projections of the sentence embeddings to their first principal component
    :return: scores, scores[i] is the matching score of the pair i
    """
    emb1 = get_weighted_average(We, x1, w1)
    emb2 = get_weighted_average(We, x2, w2)
    if  params.rmpc > 0:
        emb1 = remove_pc(emb1, params.rmpc)
        emb2 = remove_pc(emb2, params.rmpc)

    inn = (emb1 * emb2).sum(axis=1) # inner products
    emb1norm = np.sqrt((emb1 * emb1).sum(axis=1))
    emb2norm = np.sqrt((emb2 * emb2).sum(axis=1))
    scores = inn / emb1norm / emb2norm # cosine similarity
    return scores
# Out:
# ==================================
#
# done with word2weight
# done with weight4ind
# word vectors loaded from /Users/corbinrosset/Dropbox/Paragrams/paragrams-XXL-SL999.txt
# word weights computed from /Users/corbinrosset/Dropbox/Arora/QA-code/src/WordEmdgs/SIF/auxiliary_data/enwiki_vocab_min200.txt using parameter a=0.010000
# *** remove the first 0 principal components ***
# done with Hamas-base.terrorism.terrorist_organization.considered_terrorist_by-Israel
# done with Iraq-military.military_combatant.military_conflicts-U.S.
# done with U.S.-military.military_combatant.military_conflicts-Iraq
# done with US-military.military_combatant.military_conflicts-Iraq
# done with Iraq-military.military_combatant.military_conflicts-US
# done with U.S.-location.statistical_region.places_exported_to-China
# done with China-location.statistical_region.places_imported_from-U.S.
# done with Japan-location.location.adjoin_s-China
# done with China-location.location.adjoin_s-Japan
# done with United States-location.statistical_region.places_exported_to-China
# done with China-location.statistical_region.places_imported_from-United States
# done with US-location.statistical_region.places_exported_to-China
# done with China-location.statistical_region.places_imported_from-US
# done with Canada-location.location.adjoin_s-United States
# done with Canada-location.statistical_region.places_imported_from-United States
# done with United States-base.sharing.sharing_location.shared_here-Canada
# done with Canada-base.sharing.sharing_location.shared_here-United States
# done with Canada-location.statistical_region.places_exported_to-United States
# done with United States-location.statistical_region.places_imported_from-Canada
# done with United States-military.military_combatant.military_conflicts-Canada
# done with United States-location.location.adjoin_s-Canada
# done with Canada-military.military_combatant.military_conflicts-United States
# done with United States-location.statistical_region.places_exported_to-Canada
# done with India-location.location.adjoin_s-China
# done with China-location.location.adjoin_s-India
# done with US-location.statistical_region.places_imported_from-UK
# done with UK-user.skud.embassies_and_consulates.embassy.ambassadors-US
# done with UK-base.sharing.sharing_location.shared_here-US
# done with US-base.sharing.sharing_location.shared_here-UK
# done with UK-location.statistical_region.places_exported_to-US
# done with US-user.skud.embassies_and_consulates.embassy.ambassadors-UK
# done with US-location.statistical_region.places_exported_to-UK
# done with US-military.military_combatant.military_conflicts-UK
# done with UK-military.military_combatant.military_conflicts-US
# done with UK-location.statistical_region.places_imported_from-US
# done with U.S.-government.governmental_jurisdiction.governing_officials-Bush
# done with U.S.-government.governmental_jurisdiction.governing_officials-Bush
# done with Bush-people.person.nationality-U.S.
# done with Bush-government.politician.government_positions_held-U.S.
# done with Bush-government.political_appointer.appointees-U.S.
# done with Iraq-location.location.adjoin_s-Iran
# done with Iran-location.location.adjoin_s-Iraq
# done with United States-location.statistical_region.places_imported_from-Japan
# done with Japan-location.statistical_region.places_exported_to-United States
# done with United States-location.statistical_region.places_exported_to-Japan
# done with Japan-location.statistical_region.places_imported_from-United States
# done with Germany-military.military_combatant.military_conflicts-France
# done with France-military.military_combatant.military_conflicts-Germany
# done with France-location.location.adjoin_s-Germany
# done with Germany-location.location.adjoin_s-France
# done with American-military.military_combatant.military_conflicts-Iraq
# done with Iraq-military.military_combatant.military_conflicts-American
# done with China-location.country.administrative_divisions-Beijing
# done with China-location.location.contains-Beijing
# done with Beijing-base.biblioness.bibs_location.country-China
# done with China-base.aareas.schema.administrative_area.administrative_children-Beijing
# done with Beijing-location.location.containedby-China
# done with Beijing-base.aareas.schema.administrative_area.administrative_parent-China
# done with Beijing-location.administrative_division.country-China
# done with China-location.country.capital-Beijing
# done with India-location.location.adjoin_s-Pakistan
# done with Pakistan-location.location.adjoin_s-India
# done with Hamas-base.terrorism.terrorist_organization.considered_terrorist_by-Israeli
# done with Hamas-organization.organization.headquarters-Gaza
# done with France-location.location.adjoin_s-Spain
# done with Spain-location.location.adjoin_s-France
# done with France-location.location.adjoin_s-Italy
# done with Italy-location.location.adjoin_s-France
# done with France-military.military_combatant.military_conflicts-Italy
# done with Italy-military.military_combatant.military_conflicts-France
# done with Iraq-military.military_combatant.military_conflicts-United States
# done with United States-military.military_combatant.military_conflicts-Iraq
# done with Japan-location.statistical_region.places_exported_to-U.S.
# done with Japan-location.statistical_region.places_imported_from-U.S.
# done with U.S.-location.statistical_region.places_imported_from-Japan
# done with U.S.-location.statistical_region.places_exported_to-Japan
# done with British-location.statistical_region.places_imported_from-American
# done with British-location.statistical_region.places_exported_to-American
# done with American-location.statistical_region.places_imported_from-British
# done with British-military.military_combatant.military_conflicts-American
# done with British-user.skud.embassies_and_consulates.embassy.ambassadors-American
# done with American-base.sharing.sharing_location.shared_here-British
# done with British-base.sharing.sharing_location.shared_here-American
# done with American-user.skud.embassies_and_consulates.embassy.ambassadors-British
# done with American-military.military_combatant.military_conflicts-British
# done with American-location.statistical_region.places_exported_to-British
# done with U.S.-military.military_combatant.military_conflicts-Canada
# done with U.S.-location.statistical_region.places_exported_to-Canada
# done with Canada-location.statistical_region.places_imported_from-U.S.
# done with Canada-military.military_combatant.military_conflicts-U.S.
# done with Canada-base.sharing.sharing_location.shared_here-U.S.
# done with U.S.-location.location.adjoin_s-Canada
# done with Canada-location.statistical_region.places_exported_to-U.S.
# done with Canada-location.location.adjoin_s-U.S.
# done with U.S.-location.statistical_region.places_imported_from-Canada
# done with U.S.-base.sharing.sharing_location.shared_here-Canada
# done with U.S.-user.skud.embassies_and_consulates.embassy.ambassadors-Iran
# done with Apple-business.consumer_company.product_lines-iPhone
# done with iPhone-user.randy.default_domain.consumer_electronics.manufacturer-Apple
# done with iPhone-user.robert.mobile_phones.product.brand-Apple
# done with iPhone-computer.computer.manufacturer-Apple
# done with iPhone-business.product_line.producer_s-Apple
# done with Apple-computer.computer_manufacturer_brand.computer_models-iPhone
# done with iPhone-user.robert.mobile_phones.mobile_phone.brand-Apple
# done with Apple-user.robert.mobile_phones.product_brand.products-iPhone
# done with Apple-business.business_operation.competitive_space-iPhone
# done with Apple-base.schemastaging.organization_extra.phone_number-iPhone
# done with U.S.-government.governmental_jurisdiction.government_bodies-Congress
# done with Congress-government.governmental_body.jurisdiction-U.S.
# done with Spanish-location.location.adjoin_s-French
# done with French-location.location.adjoin_s-Spanish
# done with US-user.skud.embassies_and_consulates.embassy.ambassadors-Iran
# done with German-military.military_combatant.military_conflicts-French
# done with French-military.military_combatant.military_conflicts-German
# done with German-location.location.adjoin_s-French
# done with French-location.location.adjoin_s-German
# done with Taiwan-location.location.coterminous_with-China
# done with Taiwan-location.location.adjoin_s-China
# done with China-location.location.coterminous_with-Taiwan
# done with China-location.location.adjoin_s-Taiwan
# done with Israel-location.location.adjoin_s-Egypt
# done with Egypt-location.location.adjoin_s-Israel
# done with United States-location.statistical_region.places_exported_to-France
# done with France-military.military_combatant.military_conflicts-United States
# done with France-location.statistical_region.places_imported_from-United States
# done with United States-location.statistical_region.places_imported_from-France
# done with United States-military.military_combatant.military_conflicts-France
# done with France-location.statistical_region.places_exported_to-United States
# done with French-location.location.contains-Paris
# done with Paris-location.administrative_division.country-French
# done with Paris-location.location.containedby-French
# done with Paris-location.administrative_division.second_level_division_of-French
# done with French-base.locations.countries.cities_within-Paris
# done with French-location.country.capital-Paris
# done with Paris-base.locations.cities_and_towns.country-French
# done with French-location.country.administrative_divisions-Paris
# done with Paris-base.biblioness.bibs_location.country-French
# done with French-location.country.second_level_divisions-Paris
# done with Paris-user.juniorbonner.default_domain.capital_city.capital_of-French
# done with Germany-location.statistical_region.places_imported_from-United States
# done with Germany-military.military_combatant.military_conflicts-United States
# done with Germany-location.statistical_region.places_exported_to-United States
# done with United States-location.statistical_region.places_exported_to-Germany
# done with United States-military.military_combatant.military_conflicts-Germany
# done with United States-location.statistical_region.places_imported_from-Germany
# done with Chinese-location.location.adjoin_s-Japanese
# done with Japanese-location.location.adjoin_s-Chinese
# done with US-location.statistical_region.places_exported_to-Japan
# done with Japan-location.statistical_region.places_imported_from-US
# done with US-location.statistical_region.places_imported_from-Japan
# done with Japan-location.statistical_region.places_exported_to-US
# done with Iraqi-military.military_combatant.military_conflicts-U.S.
# done with U.S.-military.military_combatant.military_conflicts-Iraqi
# done with U.S.-base.aareas.schema.administrative_area.administrative_children-Washington
# done with U.S.-location.location.contains-Washington
# done with U.S.-location.country.administrative_divisions-Washington
# done with U.S.-location.country.first_level_divisions-Washington
# done with Washington-location.administrative_division.first_level_division_of-U.S.
# done with Washington-location.administrative_division.country-U.S.
# done with Washington-base.aareas.schema.administrative_area.administrative_parent-U.S.
# done with Washington-base.biblioness.bibs_location.country-U.S.
# done with Washington-location.location.containedby-U.S.
# done with U.S.-location.country.capital-Washington
# done with Taliban-organization.organization.geographic_scope-Afghanistan
# done with Afghanistan-organization.organization_scope.organizations_with_this_scope-Taliban
# done with Russia-location.location.adjoin_s-China
# done with China-location.location.adjoin_s-Russia
# done with Japanese-location.statistical_region.places_exported_to-American
# done with American-location.statistical_region.places_imported_from-Japanese
# done with American-location.statistical_region.places_exported_to-Japanese
# done with Japanese-location.statistical_region.places_imported_from-American
# done with Australia-location.location.adjoin_s-New Zealand
# done with Australia-military.military_combatant.casualties-New Zealand
# done with New Zealand-military.military_combatant.force_deployments-Australia
# done with New Zealand-military.military_combatant.military_conflicts-Australia
# done with Australia-military.military_combatant.force_deployments-New Zealand
# done with Australia-location.statistical_region.places_imported_from-New Zealand
# done with New Zealand-location.location.adjoin_s-Australia
# done with New Zealand-location.statistical_region.places_exported_to-Australia
# done with Australia-military.military_combatant.military_conflicts-New Zealand
# done with New Zealand-military.military_combatant.casualties-Australia
# done with Australia-military.military_combatant.casualties-Canada
# done with Australia-military.military_combatant.military_conflicts-Canada
# done with Canada-military.military_combatant.military_conflicts-Australia
# done with Canada-military.military_combatant.casualties-Australia
# done with Australia-location.statistical_region.places_imported_from-United States
# done with United States-user.skud.embassies_and_consulates.embassy.ambassadors-Australia
# done with United States-location.statistical_region.places_exported_to-Australia
# done with Australia-military.military_combatant.force_deployments-United States
# done with United States-military.military_combatant.force_deployments-Australia
# done with Australia-military.military_combatant.military_conflicts-United States
# done with Australia-military.military_combatant.casualties-United States
# done with United States-military.military_combatant.casualties-Australia
# done with United States-military.military_combatant.military_conflicts-Australia
# done with American-government.governmental_jurisdiction.governing_officials-Bush
# done with American-government.governmental_jurisdiction.governing_officials-Bush
# done with Bush-government.politician.government_positions_held-American
# done with Bush-government.political_appointer.appointees-American
# done with Bush-people.person.nationality-American
# done with Afghanistan-location.statistical_region.places_imported_from-U.S.
# done with U.S.-location.statistical_region.places_exported_to-Afghanistan
# done with U.S.-location.statistical_region.places_imported_from-Afghanistan
# done with Afghanistan-location.statistical_region.places_exported_to-U.S.
# done with Japan-location.statistical_region.places_imported_from-Canada
# done with Canada-location.statistical_region.places_exported_to-Japan
# done with Canada-location.statistical_region.places_imported_from-Japan
# done with Japan-location.statistical_region.places_exported_to-Canada
# done with Mexico-military.military_combatant.military_conflicts-United States
# done with United States-location.location.adjoin_s-Mexico
# done with Mexico-location.statistical_region.places_imported_from-United States
# done with Mexico-location.location.adjoin_s-United States
# done with United States-location.statistical_region.places_imported_from-Mexico
# done with United States-location.statistical_region.places_exported_to-Mexico
# done with Mexico-location.statistical_region.places_exported_to-United States
# done with United States-military.military_combatant.military_conflicts-Mexico
# done with Canada-base.sharing.sharing_location.shared_here-US
# done with US-location.location.adjoin_s-Canada
# done with Canada-military.military_combatant.military_conflicts-US
# done with US-location.statistical_region.places_imported_from-Canada
# done with US-military.military_combatant.military_conflicts-Canada
# done with US-location.statistical_region.places_exported_to-Canada
# done with Canada-location.location.adjoin_s-US
# done with Canada-location.statistical_region.places_exported_to-US
# done with US-base.sharing.sharing_location.shared_here-Canada
# done with Canada-location.statistical_region.places_imported_from-US
# done with Bush-government.politician.government_positions_held-US
# done with Bush-government.political_appointer.appointees-US
# done with Bush-people.person.nationality-US
# done with US-government.governmental_jurisdiction.governing_officials-Bush
# done with US-government.governmental_jurisdiction.governing_officials-Bush
# done with Obama-government.political_appointer.appointees-Clinton
# done with Clinton-base.government2.appointed_official.appointments-Obama
# done with Obama-people.appointer.appointment_made-Clinton
# done with Clinton-base.endorsements.endorsing_person.endorsed-Obama
# done with Obama-base.endorsements.endorsee.personal_endorsements-Clinton
# done with Clinton-people.appointee.position-Obama
# done with Clinton-government.politician.government_positions_held-Obama
# done with France-location.location.primarily_containedby-Europe
# done with France-location.location.partially_contained_by-Europe
# done with Europe-location.location.contains_major_portion_of-France
# done with Europe-location.location.partially_contains-France
# done with France-location.location.partially_containedby-Europe
# done with Europe-location.location.partiallycontains-France
# done with French-location.location.adjoin_s-British
# done with French-military.military_combatant.military_conflicts-British
# done with British-military.military_combatant.casualties-French
# done with British-military.military_combatant.military_conflicts-French
# done with French-military.military_combatant.casualties-British
# done with British-location.location.adjoin_s-French
# done with London-base.biblioness.bibs_location.country-UK
# done with London-location.location.containedby-UK
# done with London-user.juniorbonner.default_domain.capital_city.capital_of-UK
# done with UK-location.country.capital-London
# done with UK-location.location.contains-London
# done with Lebanon-location.location.adjoin_s-Israel
# done with Israel-location.location.adjoin_s-Lebanon
# done with Germany-base.locations.countries.continent-Europe
# done with Germany-location.location.containedby-Europe
# done with Europe-location.location.contains-Germany
# done with Europe-base.locations.continents.countries_within-Germany
# done with Russia-military.military_combatant.military_conflicts-United States
# done with United States-military.military_combatant.military_conflicts-Russia
# done with Israel-location.location.containedby-Middle East
# done with Middle East-location.location.contains-Israel
# done with Italian-location.location.adjoin_s-French
# done with Italian-military.military_combatant.military_conflicts-French
# done with French-location.location.adjoin_s-Italian
# done with French-military.military_combatant.military_conflicts-Italian
# done with Russian-location.country.administrative_divisions-Moscow
# done with Moscow-base.biblioness.bibs_location.country-Russian
# done with Russian-location.country.capital-Moscow
# done with Moscow-location.administrative_division.country-Russian
# done with Russian-location.location.contains-Moscow
# done with Moscow-location.location.containedby-Russian
# done with White House-architecture.building.occupant-Bush
# done with Bush-user.dfhuynh.default_domain.assassinated_person.assassination-White House
# done with Bush-architecture.building_occupant.buildings_occupied-White House
# done with United States-user.skud.embassies_and_consulates.embassy.ambassadors-Iran
# done with Germany-military.military_combatant.military_conflicts-Canada
# done with Canada-military.military_combatant.military_conflicts-Germany
# done with Russia-military.military_combatant.military_conflicts-Germany
# done with Germany-military.military_combatant.military_conflicts-Russia
# done with Pakistan-location.statistical_region.places_exported_to-Afghanistan
# done with Afghanistan-location.statistical_region.places_exported_to-Pakistan
# done with Pakistan-location.statistical_region.places_imported_from-Afghanistan
# done with Afghanistan-location.statistical_region.places_imported_from-Pakistan
# done with Afghanistan-location.location.adjoin_s-Pakistan
# done with Pakistan-location.location.adjoin_s-Afghanistan
# done with France-location.location.contains-Paris
# done with France-location.country.second_level_divisions-Paris
# done with France-location.country.capital-Paris
# done with Paris-location.administrative_division.country-France
# done with Paris-base.biblioness.bibs_location.country-France
# done with Paris-location.administrative_division.second_level_division_of-France
# done with Paris-user.juniorbonner.default_domain.capital_city.capital_of-France
# done with France-location.country.administrative_divisions-Paris
# done with France-base.locations.countries.cities_within-Paris
# done with Paris-base.locations.cities_and_towns.country-France
# done with Paris-location.location.containedby-France
# done with Switzerland-location.location.adjoin_s-Germany
# done with Switzerland-user.lapax.default_domain.landlocked_country.surrounded_by-Germany
# done with Germany-location.location.adjoin_s-Switzerland
# done with Mexico-location.statistical_region.places_exported_to-U.S.
# done with Mexico-location.statistical_region.places_imported_from-U.S.
# done with Mexico-military.military_combatant.military_conflicts-U.S.
# done with Mexico-location.location.adjoin_s-U.S.
# done with U.S.-military.military_combatant.military_conflicts-Mexico
# done with U.S.-location.statistical_region.places_imported_from-Mexico
# done with U.S.-location.location.adjoin_s-Mexico
# done with U.S.-location.statistical_region.places_exported_to-Mexico
# done with Switzerland-user.lapax.default_domain.landlocked_country.surrounded_by-France
# done with Switzerland-location.location.adjoin_s-France
# done with France-military.military_combatant.casualties-Canada
# done with France-location.location.adjoin_s-Switzerland
# done with France-military.military_combatant.military_conflicts-Canada
# done with Canada-military.military_combatant.casualties-France
# done with Canada-military.military_combatant.military_conflicts-France
# done with Muslims-dataworld.gardening_hint.split_to-Islam
# done with Earth-base.satelites.natural_satellite.orbited_body-Sun
# done with Earth-base.exoplanetology.exoplanet.parent_star-Sun
# done with Sun-base.satelites.orbited_body.natural_satellite_s-Earth
# done with Sun-astronomy.orbital_relationship.orbited_by-Earth
# done with Earth-astronomy.orbital_relationship.orbits-Sun
# done with Sun-astronomy.star.planet_s-Earth
# done with European-organization.organization_scope.organizations_with_this_scope-EU
# done with European-location.location.contains-EU
# done with EU-location.location.containedby-European
# done with EU-organization.organization.geographic_scope-European
# done with Beijing-location.administrative_division.country-Chinese
# done with Beijing-base.aareas.schema.administrative_area.administrative_parent-Chinese
# done with Chinese-location.country.capital-Beijing
# done with Beijing-base.biblioness.bibs_location.country-Chinese
# done with Beijing-location.location.containedby-Chinese
# done with Chinese-base.aareas.schema.administrative_area.administrative_children-Beijing
# done with Chinese-location.country.administrative_divisions-Beijing
# done with Chinese-location.location.contains-Beijing
# done with Russia-location.country.capital-Moscow
# done with Moscow-location.administrative_division.country-Russia
# done with Russia-location.location.contains-Moscow
# done with Moscow-base.biblioness.bibs_location.country-Russia
# done with Moscow-location.location.containedby-Russia
# done with Russia-location.country.administrative_divisions-Moscow
# done with Europe-location.location.adjoin_s-Asia
# done with Asia-location.location.adjoin_s-Europe
# done with British-location.country.capital-London
# done with London-user.juniorbonner.default_domain.capital_city.capital_of-British
# done with British-location.location.contains-London
# done with London-base.biblioness.bibs_location.country-British
# done with London-location.location.containedby-British
# done with Windows-computer.operating_system.developer-Microsoft
# done with Microsoft-computer.software_developer.software-Windows
# done with Windows-computer.software.developer-Microsoft
# done with Windows-law.invention.inventor-Microsoft
# done with Microsoft-computer.operating_system_developer.operating_systems_developed-Windows
# done with Microsoft-law.inventor.inventions-Windows
# done with Muslim-dataworld.gardening_hint.split_to-Islam
# done with China-location.country.administrative_divisions-Hong Kong
# done with Hong Kong-base.aareas.schema.administrative_area.administrative_parent-China
# done with China-location.location.contains-Hong Kong
# done with Hong Kong-base.biblioness.bibs_location.country-China
# done with China-base.aareas.schema.administrative_area.administrative_children-Hong Kong
# done with Hong Kong-location.administrative_division.country-China
# done with Hong Kong-location.location.containedby-China
# done with Russia-location.location.adjoin_s-Ukraine
# done with Ukraine-location.location.adjoin_s-Russia
# done with American-location.statistical_region.places_exported_to-French
# done with American-military.military_combatant.military_conflicts-French
# done with French-military.military_combatant.military_conflicts-American
# done with French-location.statistical_region.places_exported_to-American
# done with French-location.statistical_region.places_imported_from-American
# done with American-location.statistical_region.places_imported_from-French
# done with Germany-military.military_combatant.military_conflicts-Australia
# done with Australia-military.military_combatant.military_conflicts-Germany
# done with US-location.statistical_region.places_exported_to-Afghanistan
# done with US-location.statistical_region.places_imported_from-Afghanistan
# done with Afghanistan-location.statistical_region.places_exported_to-US
# done with Afghanistan-location.statistical_region.places_imported_from-US
# done with Israel-location.location.adjoin_s-Syria
# done with Syria-location.location.adjoin_s-Israel
# done with Jesus-symbols.name_source.namesakes-Christian
# done with Christian-symbols.namesake.named_after-Jesus
# done with Russia-military.military_combatant.military_conflicts-U.S.
# done with U.S.-military.military_combatant.military_conflicts-Russia
# done with Iraqi-military.military_combatant.military_conflicts-US
# done with US-military.military_combatant.military_conflicts-Iraqi
# done with European-location.location.contains_major_portion_of-France
# done with France-location.location.partially_containedby-European
# done with France-location.location.partially_contained_by-European
# done with European-location.location.partiallycontains-France
# done with France-location.location.primarily_containedby-European
# done with European-location.location.partially_contains-France
# done with Australia-military.military_combatant.casualties-France
# done with Australia-military.military_combatant.military_conflicts-France
# done with France-military.military_combatant.military_conflicts-Australia
# done with France-military.military_combatant.casualties-Australia
# done with France-military.military_combatant.military_conflicts-Russia
# done with Russia-military.military_combatant.military_conflicts-France
# done with Obama-government.politician.party-Democratic
# done with Democratic-government.political_party.politicians_in_this_party-Obama
# done with Obama-government.political_appointer.appointees-America
# done with America-government.governmental_jurisdiction.governing_officials-Obama
# done with America-government.governmental_jurisdiction.governing_officials-Obama
# done with Obama-people.person.nationality-America
# done with Obama-government.politician.government_positions_held-America
# done with USA-military.military_combatant.military_conflicts-UK
# done with UK-location.statistical_region.places_imported_from-USA
# done with UK-user.skud.embassies_and_consulates.embassy.ambassadors-USA
# done with UK-military.military_combatant.military_conflicts-USA
# done with USA-user.skud.embassies_and_consulates.embassy.ambassadors-UK
# done with USA-location.statistical_region.places_imported_from-UK
# done with USA-base.sharing.sharing_location.shared_here-UK
# done with USA-location.statistical_region.places_exported_to-UK
# done with UK-base.sharing.sharing_location.shared_here-USA
# done with UK-location.statistical_region.places_exported_to-USA
# done with New York-location.administrative_division.country-U.S.
# done with New York-location.location.containedby-U.S.
# done with New York-base.biblioness.bibs_location.country-U.S.
# done with U.S.-location.country.administrative_divisions-New York
# done with U.S.-location.location.contains-New York
# done with Israel-base.locations.countries.counties_within-West Bank
# done with West Bank-base.locations.counties_parishes_and_boroughs.country-Israel
# done with West Bank-location.location.adjoin_s-Israel
# done with Israel-location.location.adjoin_s-West Bank
# done with Europe-location.location.partially_contains-Russia
# done with Russia-location.location.partially_containedby-Europe
# done with Europe-location.location.partiallycontains-Russia
# done with Russia-base.locations.countries.continent-Europe
# done with Europe-base.locations.continents.countries_within-Russia
# done with Russia-location.location.partially_contained_by-Europe
# done with Iraq-location.location.contains-Baghdad
# done with Iraq-location.country.capital-Baghdad
# done with Baghdad-location.location.containedby-Iraq
# done with Japanese-location.statistical_region.places_exported_to-U.S.
# done with Japanese-location.statistical_region.places_imported_from-U.S.
# done with U.S.-location.statistical_region.places_exported_to-Japanese
# done with U.S.-location.statistical_region.places_imported_from-Japanese
# done with Europe-location.location.contains-UK
# done with Europe-base.locations.continents.countries_within-UK
# done with UK-base.locations.countries.continent-Europe
# done with UK-location.location.containedby-Europe
# done with Canada-military.military_combatant.military_conflicts-Mexico
# done with Mexico-military.military_combatant.military_conflicts-Canada
# done with European-location.location.contains-Germany
# done with Germany-location.location.containedby-European
# done with European-base.locations.continents.countries_within-Germany
# done with Germany-base.locations.countries.continent-European
# done with American-government.governmental_jurisdiction.governing_officials-Obama
# done with Obama-people.person.nationality-American
# done with Obama-government.politician.government_positions_held-American
# done with Obama-government.political_appointer.appointees-American
# done with American-government.governmental_jurisdiction.governing_officials-Obama
# done with New York-base.biblioness.bibs_location.country-United States
# done with United States-location.country.administrative_divisions-New York
# done with New York-location.administrative_division.country-United States
# done with United States-location.location.contains-New York
# done with New York-location.location.containedby-United States
# done with Japan-location.location.contains-Tokyo
# done with Japan-location.country.capital-Tokyo
# done with Tokyo-base.aareas.schema.administrative_area.administrative_parent-Japan
# done with Tokyo-location.administrative_division.country-Japan
# done with Japan-location.country.administrative_divisions-Tokyo
# done with Tokyo-base.biblioness.bibs_location.country-Japan
# done with Tokyo-location.location.containedby-Japan
# done with Japan-base.aareas.schema.administrative_area.administrative_children-Tokyo
# done with French-location.location.partially_contained_by-European
# done with European-location.location.partially_contains-French
# done with French-location.location.partially_containedby-European
# done with French-location.location.primarily_containedby-European
# done with European-location.location.contains_major_portion_of-French
# done with European-location.location.partiallycontains-French
# done with US-military.military_combatant.military_conflicts-Russia
# done with Russia-military.military_combatant.military_conflicts-US
# done with Russian-military.military_combatant.military_conflicts-German
# done with German-military.military_combatant.military_conflicts-Russian
# done with Chinese-location.statistical_region.places_imported_from-U.S.
# done with U.S.-location.statistical_region.places_exported_to-Chinese
# done with US-location.country.capital-Washington
# done with Washington-base.biblioness.bibs_location.country-US
# done with US-base.aareas.schema.administrative_area.administrative_children-Washington
# done with Washington-location.administrative_division.country-US
# done with US-location.location.contains-Washington
# done with Washington-location.location.containedby-US
# done with US-location.country.administrative_divisions-Washington
# done with Washington-location.administrative_division.first_level_division_of-US
# done with Washington-base.aareas.schema.administrative_area.administrative_parent-US
# done with US-location.country.first_level_divisions-Washington
# done with U.S.-government.governmental_jurisdiction.governing_officials-Obama
# done with U.S.-government.governmental_jurisdiction.governing_officials-Obama
# done with Obama-government.politician.government_positions_held-U.S.
# done with Obama-people.person.nationality-U.S.
# done with Obama-government.political_appointer.appointees-U.S.
# done with Canada-base.sharing.sharing_location.shared_here-USA
# done with Canada-location.statistical_region.places_exported_to-USA
# done with Canada-location.statistical_region.places_imported_from-USA
# done with USA-base.sharing.sharing_location.shared_here-Canada
# done with Canada-military.military_combatant.military_conflicts-USA
# done with USA-location.statistical_region.places_imported_from-Canada
# done with USA-location.location.adjoin_s-Canada
# done with USA-location.statistical_region.places_exported_to-Canada
# done with Canada-location.location.adjoin_s-USA
# done with USA-military.military_combatant.military_conflicts-Canada
# done with Israel-location.location.adjoin_s-Gaza Strip
# done with Gaza Strip-base.locations.counties_parishes_and_boroughs.country-Israel
# done with Israel-base.locations.countries.counties_within-Gaza Strip
# done with Gaza Strip-location.location.adjoin_s-Israel
# done with Muslim-dataworld.gardening_hint.split_to-Islamic
# done with United States-government.governmental_jurisdiction.government_bodies-Congress
# done with Congress-government.governmental_body.jurisdiction-United States
# done with French-military.military_combatant.military_conflicts-Russian
# done with Russian-military.military_combatant.military_conflicts-French
# done with UK-military.military_combatant.force_deployments-Australia
# done with UK-military.military_combatant.military_conflicts-Australia
# done with Australia-military.military_combatant.casualties-UK
# done with Australia-military.military_combatant.force_deployments-UK
# done with UK-military.military_combatant.casualties-Australia
# done with Australia-military.military_combatant.military_conflicts-UK
# done with India-location.country.administrative_divisions-Mumbai
# done with India-location.location.contains-Mumbai
# done with Mumbai-location.location.containedby-India
# done with Mumbai-location.administrative_division.country-India
# done with Mumbai-base.biblioness.bibs_location.country-India
# done with Germany-location.location.adjoin_s-Austria
# done with Austria-location.location.adjoin_s-Germany
# done with Austria-user.lapax.default_domain.landlocked_country.surrounded_by-Germany
# done with Christian-religion.adherents.religion-Christianity
# done with Christianity-religion.religion.collective_term_for_adherents-Christian
# done with Canada-military.military_combatant.military_conflicts-New Zealand
# done with Canada-base.sharing.sharing_location.shared_here-New Zealand
# done with New Zealand-military.military_combatant.military_conflicts-Canada
# done with New Zealand-base.sharing.sharing_location.shared_here-Canada
# done with Australia-military.military_combatant.casualties-US
# done with US-user.skud.embassies_and_consulates.embassy.ambassadors-Australia
# done with US-location.statistical_region.places_exported_to-Australia
# done with US-military.military_combatant.military_conflicts-Australia
# done with Australia-military.military_combatant.force_deployments-US
# done with US-military.military_combatant.force_deployments-Australia
# done with Australia-location.statistical_region.places_imported_from-US
# done with US-military.military_combatant.casualties-Australia
# done with Australia-military.military_combatant.military_conflicts-US
# done with Christians-symbols.namesake.named_after-Jesus
# done with Jesus-symbols.name_source.namesakes-Christians
# done with Belgium-location.location.adjoin_s-France
# done with France-location.location.adjoin_s-Belgium
# done with Belgium-military.military_combatant.military_conflicts-France
# done with France-military.military_combatant.military_conflicts-Belgium
# done with England-location.location.contains-London
# done with England-location.country.capital-London
# done with London-location.location.containedby-England
# done with Germany-location.statistical_region.places_exported_to-USA
# done with Germany-location.statistical_region.places_imported_from-USA
# done with USA-location.statistical_region.places_exported_to-Germany
# done with USA-location.statistical_region.places_imported_from-Germany
# done with Germany-military.military_combatant.military_conflicts-USA
# done with USA-military.military_combatant.military_conflicts-Germany
# done with United States-government.governmental_jurisdiction.governing_officials-Bush
# done with United States-government.governmental_jurisdiction.governing_officials-Bush
# done with Bush-government.politician.government_positions_held-United States
# done with Bush-people.person.nationality-United States
# done with Bush-government.political_appointer.appointees-United States
# done with Baghdad-location.location.containedby-Iraqi
# done with Iraqi-location.country.capital-Baghdad
# done with Iraqi-location.location.contains-Baghdad
# done with UK-military.military_combatant.military_conflicts-France
# done with UK-location.location.adjoin_s-France
# done with UK-military.military_combatant.casualties-France
# done with France-military.military_combatant.military_conflicts-UK
# done with France-military.military_combatant.casualties-UK
# done with France-location.location.adjoin_s-UK
# done with Germany-military.military_combatant.military_conflicts-UK
# done with UK-military.military_combatant.military_conflicts-Germany
# done with Italy-location.location.adjoin_s-Austria
# done with Austria-location.location.adjoin_s-Italy
# done with Austria-user.lapax.default_domain.landlocked_country.surrounded_by-Italy
# done with Hezbollah-base.terrorism.terrorist_organization.considered_terrorist_by-Israel
# done with Germany-location.location.adjoin_s-Poland
# done with Poland-location.location.adjoin_s-Germany
# done with Italy-military.military_combatant.military_conflicts-Australia
# done with Australia-military.military_combatant.military_conflicts-Italy
# done with Middle East-location.location.contains-Iraq
# done with Iraq-location.location.containedby-Middle East
# done with Chinese-location.statistical_region.places_imported_from-American
# done with American-location.statistical_region.places_exported_to-Chinese
# done with Germany-military.military_combatant.military_conflicts-Belgium
# done with Belgium-military.military_combatant.military_conflicts-Germany
# done with Belgium-location.location.adjoin_s-Germany
# done with Germany-location.location.adjoin_s-Belgium
# done with Asia-base.locations.continents.countries_within-China
# done with China-base.locations.countries.continent-Asia
# done with China-location.location.containedby-Asia
# done with Asia-location.location.contains-China
# done with Netherlands-location.location.adjoin_s-Germany
# done with Germany-military.military_combatant.military_conflicts-Netherlands
# done with Germany-location.location.adjoin_s-Netherlands
# done with Netherlands-military.military_combatant.military_conflicts-Germany
# done with Iran-location.country.capital-Tehran
# done with Tehran-base.biblioness.bibs_location.country-Iran
# done with Iran-location.location.contains-Tehran
# done with Tehran-location.location.containedby-Iran
# done with Canadian-base.sharing.sharing_location.shared_here-U.S.
# done with U.S.-location.location.adjoin_s-Canadian
# done with Canadian-location.statistical_region.places_exported_to-U.S.
# done with U.S.-base.sharing.sharing_location.shared_here-Canadian
# done with U.S.-military.military_combatant.military_conflicts-Canadian
# done with U.S.-location.statistical_region.places_imported_from-Canadian
# done with Canadian-military.military_combatant.military_conflicts-U.S.
# done with Canadian-location.statistical_region.places_imported_from-U.S.
# done with U.S.-location.statistical_region.places_exported_to-Canadian
# done with Canadian-location.location.adjoin_s-U.S.
# done with USA-military.military_combatant.casualties-Australia
# done with USA-military.military_combatant.force_deployments-Australia
# done with USA-military.military_combatant.military_conflicts-Australia
# done with USA-location.statistical_region.places_exported_to-Australia
# done with USA-user.skud.embassies_and_consulates.embassy.ambassadors-Australia
# done with Australia-military.military_combatant.military_conflicts-USA
# done with Australia-location.statistical_region.places_imported_from-USA
# done with Australia-military.military_combatant.force_deployments-USA
# done with Australia-military.military_combatant.casualties-USA
# done with English-dataworld.gardening_hint.split_to-British
# done with British-location.country.administrative_divisions-English
# done with British-location.location.events-English
# done with British-location.country.first_level_divisions-English
# done with English-base.biblioness.bibs_location.country-British
# done with English-location.administrative_division.first_level_division_of-British
# done with English-time.event.locations-British
# done with English-location.location.containedby-British
# done with British-base.aareas.schema.administrative_area.administrative_children-English
# done with British-location.location.contains-English
# done with English-location.administrative_division.country-British
# done with English-base.aareas.schema.administrative_area.administrative_parent-British
# done with France-military.military_combatant.military_conflicts-Netherlands
# done with Netherlands-military.military_combatant.military_conflicts-France
# done with New York-base.biblioness.bibs_location.country-American
# done with American-location.country.administrative_divisions-New York
# done with American-location.location.contains-New York
# done with New York-location.administrative_division.country-American
# done with New York-location.location.containedby-American
# done with German-location.statistical_region.places_exported_to-American
# done with American-location.statistical_region.places_exported_to-German
# done with German-location.statistical_region.places_imported_from-American
# done with American-military.military_combatant.military_conflicts-German
# done with German-military.military_combatant.military_conflicts-American
# done with American-location.statistical_region.places_imported_from-German
# done with Russia-location.location.adjoin_s-Georgia
# done with Georgia-location.location.adjoin_s-Russia
# done with Apple-base.schemastaging.organization_extra.phone_number-iPod
# done with iPod-business.brand.owner_s-Apple
# done with iPod-base.gadgets.gadget.manufacture-Apple
# done with Apple-base.engineeringdraft.product_designer.product-iPod
# done with Apple-business.consumer_company.product_lines-iPod
# done with iPod-business.product_line.producer_s-Apple
# done with Apple-business.consumer_company.brands-iPod
# done with iPod-base.engineeringdraft.manufactured_component.introduced_by-Apple
# done with iPod-user.randy.default_domain.consumer_electronics.manufacturer-Apple
# done with Saddam Hussein-government.politician.government_positions_held-Iraq
# done with Saddam Hussein-people.person.nationality-Iraq
# done with Iraq-government.governmental_jurisdiction.governing_officials-Saddam Hussein
# done with Italy-military.military_combatant.military_conflicts-United States
# done with Italy-location.statistical_region.places_exported_to-United States
# done with United States-location.statistical_region.places_imported_from-Italy
# done with United States-military.military_combatant.military_conflicts-Italy
# done with Europe-location.location.contains-Italy
# done with Italy-location.location.containedby-Europe
# done with Italy-base.locations.countries.continent-Europe
# done with Europe-base.locations.continents.countries_within-Italy
# done with Italy-location.location.adjoin_s-Switzerland
# done with Switzerland-location.location.adjoin_s-Italy
# done with Switzerland-user.lapax.default_domain.landlocked_country.surrounded_by-Italy
# done with British-military.military_combatant.military_conflicts-German
# done with German-military.military_combatant.military_conflicts-British
# done with Congress-government.governmental_body.jurisdiction-American
# done with American-government.governmental_jurisdiction.government_bodies-Congress
# done with Mac-business.product_line.producer_s-Apple
# done with Apple-business.consumer_company.brands-Mac
# done with Apple-computer.computer_manufacturer_brand.computer_lines-Mac
# done with Apple-business.consumer_company.product_lines-Mac
# done with Mac-computer.computer.manufacturer-Apple
# done with Apple-base.schemastaging.organization_extra.phone_number-Mac
# done with Apple-user.robert.mobile_phones.product_brand.products-Mac
# done with Apple-computer.computer_manufacturer_brand.computer_models-Mac
# done with Mac-business.brand.owner_s-Apple
# done with Mac-user.robert.mobile_phones.product.brand-Apple
# done with Americans-military.military_combatant.military_conflicts-Iraq
# done with Iraq-military.military_combatant.military_conflicts-Americans
# done with Europe-location.location.adjoin_s-Africa
# done with Africa-location.location.adjoin_s-Europe
# done with China-location.statistical_region.places_imported_from-American
# done with American-location.statistical_region.places_exported_to-China
# done with US-location.statistical_region.places_imported_from-Germany
# done with Germany-location.statistical_region.places_imported_from-US
# done with US-military.military_combatant.military_conflicts-Germany
# done with Germany-military.military_combatant.military_conflicts-US
# done with Germany-location.statistical_region.places_exported_to-US
# done with US-location.statistical_region.places_exported_to-Germany
# done with United Kingdom-military.military_combatant.military_conflicts-Germany
# done with Germany-military.military_combatant.military_conflicts-United Kingdom
# done with Christianity-religion.religion.deities-God
# done with God-religion.deity.deity_of-Christianity
# done with Washington-base.biblioness.bibs_location.country-United States
# done with United States-base.aareas.schema.administrative_area.administrative_children-Washington
# done with Washington-location.location.containedby-United States
# done with Washington-location.administrative_division.first_level_division_of-United States
# done with United States-location.location.contains-Washington
# done with Washington-base.aareas.schema.administrative_area.administrative_parent-United States
# done with United States-location.country.capital-Washington
# done with United States-location.country.administrative_divisions-Washington
# done with Washington-location.administrative_division.country-United States
# done with United States-location.country.first_level_divisions-Washington
# done with British-location.location.contains-England
# done with British-location.location.events-England
# done with England-base.biblioness.bibs_location.country-British
# done with British-base.aareas.schema.administrative_area.administrative_children-England
# done with British-location.country.administrative_divisions-England
# done with British-location.country.first_level_divisions-England
# done with England-base.aareas.schema.administrative_area.administrative_parent-British
# done with England-location.administrative_division.first_level_division_of-British
# done with England-time.event.locations-British
# done with England-location.administrative_division.country-British
# done with England-dataworld.gardening_hint.split_to-British
# done with England-location.location.containedby-British
# ...
# done with United Kingdom-location.location.contains-Northern Ireland
# done with United Kingdom-location.country.administrative_divisions-Northern Ireland
# done with Northern Ireland-base.aareas.schema.administrative_area.administrative_parent-United Kingdom
# done with North America-location.location.contains-Caribbean
# done with Caribbean-location.location.containedby-North America
# done with Saudi Arabia-location.location.adjoin_s-Qatar
# done with Tennessee-location.location.adjoin_s-Virginia
# done with Qatar-location.location.adjoin_s-Saudi Arabia
# done with Virginia-location.location.adjoin_s-Tennessee
# done with Mozambique-location.location.adjoin_s-Tanzania
# done with Tanzania-location.location.adjoin_s-Mozambique
# done with Netherlands-military.military_combatant.military_conflicts-New Zealand
# done with New Zealand-military.military_combatant.military_conflicts-Netherlands
# done with Netherlands-base.sharing.sharing_location.shared_here-New Zealand
# done with New Zealand-base.sharing.sharing_location.shared_here-Netherlands
# done with Norway-military.military_combatant.military_conflicts-Mexico
# done with Mexico-military.military_combatant.military_conflicts-Norway
# done with New Mexico-location.location.adjoin_s-Oklahoma
# done with Netherlands-military.military_combatant.military_conflicts-Luxembourg
# done with Oklahoma-location.location.adjoin_s-New Mexico
# done with Luxembourg-military.military_combatant.military_conflicts-Netherlands
# done with Greek-military.military_combatant.military_conflicts-Polish
# done with Polish-military.military_combatant.military_conflicts-Greek
# done with Libya-location.location.adjoin_s-Sudan
# done with Sudan-location.location.adjoin_s-Libya
# done with United Arab Emirates-location.location.adjoin_s-Saudi Arabia
# done with Saudi Arabia-location.location.adjoin_s-United Arab Emirates
# done with Oman-location.location.adjoin_s-Saudi Arabia
# done with Saudi Arabia-location.location.adjoin_s-Oman
# done with Vladimir Putin-government.politician.government_positions_held-Russian
# done with Russian-government.governmental_jurisdiction.governing_officials-Vladimir Putin
# done with Vladimir Putin-government.political_appointer.appointees-Russian
# done with Russian-government.governmental_jurisdiction.governing_officials-Vladimir Putin
# done with Vladimir Putin-people.person.nationality-Russian
# done with South Dakota-location.location.adjoin_s-Wyoming
# done with Wyoming-location.location.adjoin_s-South Dakota
# done with Roland Burris-government.politician.government_positions_held-Illinois
# done with Illinois-government.political_district.representatives-Roland Burris
# done with District of Columbia-location.location.adjoin_s-Maryland
# done with Maryland-location.location.adjoin_s-District of Columbia
# done with Perth-location.location.containedby-Australia
# done with Australia-location.location.contains-Perth
# done with Perth-base.biblioness.bibs_location.country-Australia
# done with Virginia-location.location.adjoin_s-Maryland
# done with Maryland-location.location.adjoin_s-Virginia
# done with Edmonton-base.biblioness.bibs_location.country-Canada
# done with Canada-location.location.contains-Edmonton
# done with Edmonton-location.location.containedby-Canada
# done with Slovakia-military.military_combatant.military_conflicts-Romania
# done with Romania-military.military_combatant.military_conflicts-Slovakia
# done with Sun-computer.operating_system_developer.operating_systems_developed-Solaris
# done with Solaris-computer.operating_system.developer-Sun
# done with Missouri-location.location.adjoin_s-Nebraska
# done with Nebraska-location.location.adjoin_s-Missouri
# done with Mexico-military.military_combatant.military_conflicts-Netherlands
# done with Netherlands-military.military_combatant.military_conflicts-Mexico
# done with United Kingdom-location.location.contains-Wales
# done with Wales-location.location.containedby-United Kingdom
# done with Wales-location.administrative_division.country-United Kingdom
# done with United Kingdom-location.country.first_level_divisions-Wales
# done with United Kingdom-base.aareas.schema.administrative_area.administrative_children-Wales
# done with United Kingdom-location.country.administrative_divisions-Wales
# done with Wales-location.administrative_division.first_level_division_of-United Kingdom
# done with Wales-base.aareas.schema.administrative_area.administrative_parent-United Kingdom
# done with Wales-base.biblioness.bibs_location.country-United Kingdom
# done with Australia-location.location.contains-Adelaide
# done with Adelaide-location.location.containedby-Australia
# done with Adelaide-base.biblioness.bibs_location.country-Australia
# done with British-government.governmental_jurisdiction.governing_officials-Tony Blair
# done with Senate-government.governmental_body.members-Roland Burris
# done with Tony Blair-government.politician.government_positions_held-British
# done with Roland Burris-government.politician.government_positions_held-Senate
# done with Tony Blair-people.person.nationality-British
# done with Roland Burris-base.government2.legislator.legislative_positions_held-Senate
# done with Adobe-computer.software_developer.software-Acrobat Reader
# done with Acrobat Reader-computer.software.developer-Adobe
# done with Latvia-location.location.adjoin_s-Lithuania
# done with Lithuania-location.location.adjoin_s-Latvia
# done with Bulgarian-military.military_combatant.military_conflicts-French
# done with French-military.military_combatant.military_conflicts-Bulgarian
# done with Montana-location.location.adjoin_s-North Dakota
# done with North Dakota-location.location.adjoin_s-Montana
# done with Kentucky-location.location.adjoin_s-Virginia
# done with Virginia-location.location.adjoin_s-Kentucky
# done with Greek-military.military_combatant.military_conflicts-Dutch
# done with Dutch-military.military_combatant.military_conflicts-Greek
# done with Winnipeg-base.biblioness.bibs_location.country-Canada
# done with Winnipeg-location.location.containedby-Canada
# done with Canada-location.location.contains-Winnipeg
# done with Los Angeles-base.biblioness.bibs_location.country-USA
# done with USA-location.location.contains-Los Angeles
# done with Los Angeles-location.location.containedby-USA
# done with Illinois-government.governmental_jurisdiction.governing_officials-Rod Blagojevich
# done with Chicago-base.biblioness.bibs_location.country-USA
# done with USA-location.country.administrative_divisions-Chicago
# done with Chicago-location.location.containedby-USA
# done with Rod Blagojevich-government.politician.government_positions_held-Illinois
# done with USA-location.location.contains-Chicago
# done with Chicago-location.administrative_division.country-USA
# done with Adobe Acrobat Reader-computer.software.developer-Adobe
# done with Adobe-computer.software_developer.software-Adobe Acrobat Reader
# done with PA-location.location.adjoin_s-NJ
# done with NJ-location.location.adjoin_s-PA
# done with South Dakota-location.location.adjoin_s-North Dakota
# done with North Dakota-location.location.adjoin_s-South Dakota
# done with Mahmoud Abbas-government.politician.government_positions_held-Palestinian
# done with Mahmoud Abbas-people.person.nationality-Palestinian
# done with Palestinian-government.governmental_jurisdiction.governing_officials-Mahmoud Abbas
# done with Yahoo-organization.organization.headquarters-U.S.
# done with Ehud Olmert-people.person.nationality-Israeli
# done with Israeli-government.governmental_jurisdiction.governing_officials-Ehud Olmert
# done with Ehud Olmert-government.politician.government_positions_held-Israeli
# done with Condoleezza Rice-people.person.nationality-U.S.
# done with U.S.-government.governmental_jurisdiction.governing_officials-Condoleezza Rice
# done with Condoleezza Rice-government.politician.government_positions_held-U.S.
# done with Ohio-location.location.adjoin_s-Virginia
# done with Virginia-location.location.adjoin_s-Ohio
# done with San Francisco-location.location.containedby-USA
# done with USA-location.country.second_level_divisions-San Francisco
# done with San Francisco-location.administrative_division.second_level_division_of-USA
# done with San Francisco-location.administrative_division.country-USA
# done with USA-location.country.administrative_divisions-San Francisco
# done with USA-location.location.contains-San Francisco
# done with San Francisco-base.biblioness.bibs_location.country-USA
# done with Pennsylvania-location.location.adjoin_s-Virginia
# done with Virginia-location.location.adjoin_s-Pennsylvania
# done with USA-government.governmental_jurisdiction.governing_officials-Hawaii
# done with USA-base.locations.countries.states_provinces_within-Hawaii
# done with Hawaii-government.political_district.representatives-USA
# done with Hawaii-base.biblioness.bibs_location.country-USA
# done with Hawaii-base.locations.states_and_provences.country-USA
# done with USA-location.location.contains-Hawaii
# done with Hawaii-location.administrative_division.country-USA
# done with Hawaii-location.location.containedby-USA
# done with USA-location.country.administrative_divisions-Hawaii
# done with USA-location.country.first_level_divisions-Hawaii
# done with USA-base.aareas.schema.administrative_area.administrative_children-Hawaii
# done with Hawaii-base.aareas.schema.administrative_area.administrative_parent-USA
# done with Hawaii-location.administrative_division.first_level_division_of-USA
# done with Kofi Annan-people.person.employment_history-UN
# done with UN-organization.organization.leadership-Kofi Annan
# done with Kofi Annan-business.board_member.leader_of-UN
# done with UN-award.award_winner.awards_won-Kofi Annan
# done with Kofi Annan-award.award_winner.awards_won-UN
# done with Kofi Annan-base.nobelprizes.nobel_prize_winner.nobel_honor-UN
# done with UN-business.employer.employees-Kofi Annan
# done with UN-base.nobelprizes.nobel_prize_winner.nobel_honor-Kofi Annan
# done with USA-location.location.contains-Boston
# done with Boston-base.biblioness.bibs_location.country-USA
# done with Boston-location.location.containedby-USA
# done with Chinese-location.country.languages_spoken-Portuguese
# done with Portuguese-language.human_language.countries_spoken_in-Chinese
# done with Nicolas Sarkozy-government.politician.government_positions_held-French
# done with French-government.governmental_jurisdiction.governing_officials-Nicolas Sarkozy
# done with Nicolas Sarkozy-government.political_appointer.appointees-French
# done with French-government.governmental_jurisdiction.governing_officials-Nicolas Sarkozy
# done with Nicolas Sarkozy-people.person.nationality-French
# done with British-government.governmental_jurisdiction.governing_officials-Gordon Brown
# done with Gordon Brown-government.politician.government_positions_held-British
# done with Gordon Brown-people.person.nationality-British
# done with USA-government.governmental_jurisdiction.governing_officials-Alaska
# done with Alaska-base.biblioness.bibs_location.country-USA
# done with USA-location.country.first_level_divisions-Alaska
# done with Alaska-location.administrative_division.country-USA
# done with Alaska-base.locations.states_and_provences.country-USA
# done with Alaska-government.political_district.representatives-USA
# done with USA-base.locations.countries.states_provinces_within-Alaska
# done with USA-base.aareas.schema.administrative_area.administrative_children-Alaska
# done with USA-location.country.administrative_divisions-Alaska
# done with Alaska-location.administrative_division.first_level_division_of-USA
# done with Alaska-base.aareas.schema.administrative_area.administrative_parent-USA
# done with USA-location.location.contains-Alaska
# done with Alaska-location.location.containedby-USA
# done with Windows-computer.operating_system.includes_os_versions-NT
# done with NT-computer.operating_system.parent_os-Windows
# done with NY-location.location.containedby-USA
# done with USA-location.country.administrative_divisions-NY
# done with NY-base.locations.states_and_provences.country-USA
# done with NY-government.political_district.representatives-USA
# done with USA-base.aareas.schema.administrative_area.administrative_children-NY
# done with NY-base.aareas.schema.administrative_area.administrative_parent-USA
# done with NY-location.administrative_division.country-USA
# done with USA-location.country.first_level_divisions-NY
# done with USA-base.locations.countries.states_provinces_within-NY
# done with USA-government.governmental_jurisdiction.governing_officials-NY
# done with NY-location.administrative_division.first_level_division_of-USA
# done with USA-location.location.contains-NY
# done with NY-base.biblioness.bibs_location.country-USA
# done with USA-location.location.contains-Seattle
# done with Seattle-base.biblioness.bibs_location.country-USA
# done with Seattle-location.location.containedby-USA
# done with Mahmoud Ahmadinejad-government.politician.government_positions_held-Iranian
# done with Mahmoud Ahmadinejad-people.person.nationality-Iranian
# done with Iranian-government.governmental_jurisdiction.governing_officials-Mahmoud Ahmadinejad
# done with Venezuelan-government.governmental_jurisdiction.governing_officials-Hugo Chavez
# done with Hugo Chavez-people.person.nationality-Venezuelan
# done with Hugo Chavez-government.politician.government_positions_held-Venezuelan
# done with WMV-computer.file_format.contained_by-ASF
# done with ASF-computer.file_format.container_for-WMV
# done with DXF-computer.file_format.read_by-AutoCAD
# done with DXF-computer.file_format.written_by-AutoCAD
# done with Baidu-organization.organization.phone_number-Chinese
# done with Baidu-organization.organization.headquarters-Chinese
# done with BitTorrent-computer.file_format.genre-P2P
# done with P2P-computer.file_format_genre.file_formats-BitTorrent
# done with USA-location.country.first_level_divisions-MA
# done with USA-location.country.administrative_divisions-MA
# done with MA-base.locations.states_and_provences.country-USA
# done with MA-government.political_district.representatives-USA
# done with MA-base.biblioness.bibs_location.country-USA
# done with USA-base.aareas.schema.administrative_area.administrative_children-MA
# done with MA-base.aareas.schema.administrative_area.administrative_parent-USA
# done with MA-location.administrative_division.first_level_division_of-USA
# done with MA-location.administrative_division.country-USA
# done with USA-location.location.contains-MA
# done with USA-government.governmental_jurisdiction.governing_officials-MA
# done with MA-location.location.containedby-USA
# done with USA-base.locations.countries.states_provinces_within-MA
# done with English-education.field_of_study.students_majoring-Italian
# done with Italian-education.field_of_study.students_majoring-English
# done with New York state assembly-government.governmental_body.jurisdiction-N.Y.
# done with New York state assembly-government.governmental_body.members-N.Y.
# done with N.Y.-government.governmental_jurisdiction.government_bodies-New York state assembly
# done with N.Y.-government.governmental_jurisdiction.governing_officials-New York state assembly
# done with Time Warner-organization.organization.spin_offs-Time Warner Cable
# done with Time Warner Cable-organization.organization.spun_off_from-Time Warner
# done with National Institutes of Health-organization.organization.parent-U.S. Department of Health and Human Services
# done with Drew Barrymore-celebrities.celebrity.celebrity_friends-Cameron Diaz
# done with Buffalo-base.biblioness.bibs_location.country-USA
# done with Cameron Diaz-award.award_winner.awards_won-Drew Barrymore
# done with Cameron Diaz-base.popstra.celebrity.friendship-Drew Barrymore
# done with Drew Barrymore-base.popstra.celebrity.friendship-Cameron Diaz
# done with Drew Barrymore-award.award_nominee.award_nominations-Cameron Diaz
# done with Buffalo-location.location.containedby-USA
# done with MIT Press-organization.organization.headquarters-Cambridge
# done with RIA Novosti-organization.organization.headquarters-MOSCOW
# done with AT&T-base.schemastaging.organization_extra.phone_number-Dish Network
# done with Lucy Liu-award.award_nominee.award_nominations-Cameron Diaz
# done with Cable TV-business.industry.companies-Mediacom

# %%
###############################################################################
###                 Helper Methods for Clueweb-related tasks                ###
###############################################################################

### CLUEWEB
def get_statistics(lst):
    stats = {}
    stats['mean'] = np.mean(lst)
    stats['median'] = np.median(lst)
    # stats['quartiles'] = 
    stats['standard deviation'] = np.std(lst)
    stats['mean absolute deviation'] = np.mean(np.absolute(lst - np.mean(lst)))
    stats['interquartile range'] = iqr(lst)

    # plt.clera()
    # plt.hist(lst, bins=100)
    # plt.show()

    return stats

### CLUEWEB
def get_embeddings_clueweb(We, words, data, weight4ind, params, key):
    seq, labels, sentences = [], [], []
    key = str(key[0][0]) + '-' + key[1][0] + '-' + str(key[2][0])
    for i, text_instance in enumerate(data):
        ### remember text instances are tuples ("text goes here",)
        X = data_io.getSeq(text_instance[0].strip(), words)
        labels.append(key)
        seq.append(X)
        sentences.append(text_instance)

    x1, w1 = data_io.prepare_data(seq)
    emb, embnorm = get_norm_embedding(We, x1, w1, params)
    emb = np.asarray(emb, dtype=np.float64)
    # perhaps divide each row by its L2 norm, emb /= embnorm
    return emb, labels, sentences

### CLUEWEB
def evaluate_similarity_all_pairs(We, words, data, weight4ind, scoring_function, params):
    '''data here is a dictionary of 5k of the most commonly mentioned freebase triples 
        mapping to a list of their textual instances, which is at most 40k in length. 
        The goal here is to get a sense of how similar the instances in the list are with 
        each other - there are no labels here, just output say the average/median 
        similarity score of all pairs in the list, or a subsample of all pairs. 
    '''
    triple_sim_stats = {}
    avgs = []
    prob = 0.001 
    counter = 0
    seq1, seq2 = [], []
    keys = sorted(data, key=lambda x: len(data[x]), reverse=True)
    try:
        output = open('output_similarity_all_pairs.txt', 'w')
    except:
        print 'failure'
        exit()
        
    for key in keys:
        texts = data[key]
        pairs = itertools.combinations(texts, 2)
        counter = 10000
        seq1, seq2 = [], []
        output.write('-------------------\n')
        output.write(str(key) + '\n')
        output.write('number of textual instances: ' + str(len(texts)) + '\n')

        for i, pair in enumerate(pairs):
            if random.random() > prob: ### subsample
                continue
            counter -= 1
            if counter <= 0:
                break
            pair = (pair[0][0].strip(), pair[1][0].strip())
            X1, X2 = data_io.getSeqs(pair[0],pair[1], words)
            seq1.append(X1)
            seq2.append(X2)
        output.write('length of sampled sequence: ' + str(len(seq1)) + '\n')
        assert len(seq1) == len(seq2)

        if len(seq1) == 0:
            output.write('skipped this triple!\n')
            continue
        x1,m1 = data_io.prepare_data(seq1)
        x2,m2 = data_io.prepare_data(seq2)
        m1 = data_io.seq2weight(x1, m1, weight4ind)
        m2 = data_io.seq2weight(x2, m2, weight4ind)
        scores = scoring_function(We,x1,x2,m1,m2, params)
        preds = np.squeeze(scores)
        stats = get_statistics(preds)
        output.write(pprint.pformat(stats) + '\n')
        triple_sim_stats[key] = stats
        avgs.append(stats['mean'])
        print 'done with ' + str(key[0][0]) + '-' + key[1][0] + '-' + str(key[2][0])
    output.close()
    return triple_sim_stats, avgs

# %%
# %matplotlib inline
# mpld3.enable_notebook()
mpld3.disable_notebook()

###############################################################################
###                 Manage and Visualize Clueweb Experiments                ###
###############################################################################

def t_sne(data):
    '''run_bh_tsne(data, no_dims=2, perplexity=50, theta=0.5, randseed=-1, verbose=False,initial_dims=50, use_pca=True, max_iter=1000):
        
        Run TSNE based on the Barnes-HT algorithm

        Parameters:
        ----------
        data: file or numpy.array
            The data used to run TSNE, one sample per row
        no_dims: int
        perplexity: int
        randseed: int
        theta: float
        initial_dims: int
        verbose: boolean
        use_pca: boolean
        max_iter: int
    '''

    X_2d = bh_sne(data, perplexity=30, theta=0.5) #, max_iter=600) #bh_sne(X, perplexity=50, theta=0.5)  
    return X_2d

def tooltip_style(text):
    return "<p style=\"color: #ffffff; background-color: #000000\">" + str(text) + "</p>"

def plot_clueweb(X, Y, popup_labels, title):
    '''X is a list of matrices of length n, each of which has its own class or 
    color, y. popup_labels is also a list of n lists, each containing the tag
    of individual points (rows in a matrix of X)'''

    ###############
    labels_flat = [item for sublist in Y for item in sublist]
    labels_set = set(labels_flat)
            
    fig, ax = plt.subplots(subplot_kw=dict(axisbg='#EEEEEE'), figsize=(20,20))
    
    assert len(X) == len(Y)
    if popup_labels:
        assert len(popup_labels) == len(X)
        assert np.shape(X)[0] == np.shape(popup_labels)[0]
    ax.grid(color='white', linestyle='solid')
    colors = cm.rainbow(np.linspace(0,1, len(Y)))
    color_label_map = {}
    for c, label in zip(colors, labels_set):
        color_label_map[label] = c
#     print 'labels\' colors: ' + str(color_label_map)
        
    legend_partition, legend_strings = [], [] 
    for (x, group_labels, tag) in zip(X, Y, popup_labels):
        label = group_labels[0]
        assert all(label == i for i in group_labels)
        scatter = ax.scatter(x[:, 0], x[:, 1], c = color_label_map[label], alpha=0.3, label=label)
        legend_partition.append(scatter)
        legend_strings.append(label)
#         tooltip = mpld3.plugins.PointLabelTooltip(scatter, labels=[tooltip_style(t[0]) for t in tag])
        tooltip = mpld3.plugins.PointHTMLTooltip(scatter, labels=[tooltip_style(t[0]) for t in tag])
        mpld3.plugins.connect(fig, tooltip)
        
    l_keys, l_nums, recs = [], [], []
    print 'Legend: '
    for i, (key, value) in enumerate(color_label_map.items()):
        print str(i) + ' = ' + str(key)
        l_nums.append(str(i))
        l_keys.append(key)
        recs.append(mpatches.Rectangle((0,0),1,1,fc=value))

    plt.legend(recs, l_keys, loc='upper right', fontsize=8)
    if title:
        ax.set_title(title, size=12)
        
    mpld3.save_html(fig, title + '.html')
    mpld3.show()
#     mpld3.display() # doesn't seem to work for ipython notebooks?
    return

def clueweb_tsne_experiment():
     ### T-SNE on selected triples - A COUPLE OF EXPERIMENTS NEED TO BE DONE HERE!!!!
    with open('./common_base_triples_3.txt') as g:
        ### only load textual mentions of triples with the most mentions
        keys = [eval(i.strip()) for i in g.readlines()]
        X, labels, sentences = [], [], []
        for key in keys:
            data_selected = DATA[key]
            x, labels_x, sentences_x = get_embeddings_clueweb(We, words, data_selected, weight4ind, params, key)
            if np.shape(x)[0] > 7000:  ### sample 5000 instances to reduce runtime
                idx = np.random.choice(np.shape(x)[0], 7000)
                X.append(x[idx, :])
                labels.append((np.array(labels_x)[idx]).tolist())
                sentences.append((np.array(sentences_x)[idx]).tolist())
            else:
                X.append(x)
                labels.append(labels_x)
                sentences.append(sentences_x)
            print '\t' + str(np.shape(X[-1])) + ' ' + str(key[0][0]) + '-' + key[1][0] + '-' + str(key[2][0])
        print 'done creating embeddings'
        X_stacked = np.asarray(np.vstack(tuple(X)), dtype=np.float64)
        X_2d = t_sne(X_stacked) #
        print 'done with tsne ' + str(np.shape(X_2d)) 

        ### must chunk the t-sne embeddings to match labels...
        X_2d_chunk = []
        size = 0
        for i in labels:
            X_2d_chunk.append(X_2d[size:(size + len(i))])
            size += len(i)

        for a, b, c in zip(X_2d_chunk, labels, sentences):
            assert len(a) == len(b) == len(c)
        return X_2d_chunk, labels, sentences

# %%
###############################################################################
###                                 Main                                    ###
###############################################################################


### tune weight and rmpc params in evaluation of similarity
for weightpara in weightparas:
    print '\n==================================\n'
    #### load weight for each word using idf or tf-idf
    word2weight = data_io.getWordWeight(weightfile, weightpara)
    print 'done with word2weight' 
    weight4ind = data_io.getWeight(words, word2weight)
    print 'done with weight4ind'
    
    for rmpc in rmpcs:
        print 'word vectors loaded from %s' % wordfile
        print 'word weights computed from %s using parameter a=%f' % (weightfile, weightpara)
        params.rmpc = rmpc
        print '*** remove the first %d principal components ***' % rmpc

        #################################################################
        ### modify the following lines for your purposes (clueweb or sim)
        #################################################################


        #################################################################
        #################################################################
        ### for text similarity task data:

        # for file in paraphrases_files:
        # scoring_function = weighted_average_sim_rmpc
        # triple_sim_stats, avgs = evaluate_similarity(We, words, data, weight4ind, scoring_function, params) ### only for clueweb

        # print 'average similarities per triple: ' + str(avgs)
        # print 'average of averages: ' + str(np.mean(avgs))
        # with open(data_dir + 'clueweb_triples_similarity_' + str(rmpc) + '_rmpc_' + str(weightpara) + '_weight.pkl', 'w') as f:
        #     pickle.dump(triple_sim_stats, f)

        #################################################################
        ### T-SNE
        # X, labels, sentences = get_embeddings(We, words, data, weight4ind, params)
        # t_sne(X, labels, sentences, 't-SNE on text similarity pairs')

        #################################################################
        #################################################################
        ### for clueweb data

        ### test similirity of textual instances of same FB triple...
#         scoring_function = weighted_average_sim_rmpc
#         triple_sim_stats, avgs = evaluate_similarity_all_pairs(We, words, DATA, weight4ind, scoring_function, params) ### only for clueweb
#         print 'average similarities per triple: ' + str(avgs)
#         print 'average of averages: ' + str(np.mean(avgs))
#         with open(data_dir + 'clueweb_triples_similarity_' + str(rmpc) + '_rmpc_' + str(weightpara) + '_weight.pkl', 'w') as f:
#             pickle.dump(triple_sim_stats, f)

        #################################################################
#         X_2d_chunk, labels, sentences = clueweb_tsne_experiment()
#         plot_clueweb(X_2d_chunk, labels, sentences, title='t-SNE of textual instances of most common clueweb triples (6) (sampled)')
#         print 'done'
       
            
            



###############################################################################
###                                 Dead                                    ###
###############################################################################
# Out:
# ==================================
#
# done with word2weight
# done with weight4ind
# word vectors loaded from /Users/corbinrosset/Dropbox/Paragrams/paragrams-XXL-SL999.txt
# word weights computed from /Users/corbinrosset/Dropbox/Arora/QA-code/src/WordEmdgs/SIF/auxiliary_data/enwiki_vocab_min200.txt using parameter a=0.010000
# *** remove the first 0 principal components ***
# average similarities per triple: [0.19749193555831396, 0.20312474857808788, 0.20459883202321957, 0.19340284524528908, 0.19133693525113252, 0.17689334003960899, 0.17617271059368558, 0.19142649080312249, 0.19095621396256354, 0.19819025935351914, 0.19909826007156464, 0.17746558228594977, 0.17836355078569502, 0.19578325219957063, 0.20016380450493865, 0.20142032325687911, 0.19267014371701588, 0.19587262433154348, 0.19447805595768572, 0.19518489432260344, 0.19634502298135439, 0.19424514020359956, 0.19784073314751641, 0.18290415723235481, 0.17779004738240123, 0.13170052811190189, 0.13245475642468182, 0.13456892597388947, 0.1316306660781614, 0.13110295623019746, 0.13344176377523403, 0.12990292171613688, 0.13348589735598926, 0.13053128617155857, 0.13057590701040145, 0.22018058030133669, 0.220559027815279, 0.22138926900676317, 0.2199824111822774, 0.21710390507470545, 0.19604931534534129, 0.19873574806858543, 0.21428187533537893, 0.2139458537479641, 0.21354025945465843, 0.214092105147941, 0.1887473958492574, 0.19087705110956035, 0.19241357815031812, 0.19042087578609962, 0.20416922527945711, 0.20677881090652589, 0.17413134969202176, 0.17592873291373934, 0.17352227693033026, 0.17416237330883064, 0.17436928591271311, 0.17528564518911244, 0.17517262607088266, 0.17370501364783841, 0.17472930400473446, 0.175832610626005, 0.21769166174982327, 0.21676515307770788, 0.3215936309290473, 0.32098752622380733, 0.23873126726291549, 0.24114125902300942, 0.23985005964964243, 0.23741303486099438, 0.20099818598993999, 0.2004919336707669, 0.16781755753998234, 0.16892383820348461, 0.16719750169779379, 0.1678042101490024, 0.12784267304805505, 0.12811841599677115, 0.12964980307665586, 0.12902472672062401, 0.12661146370620077, 0.12889774527827844, 0.12906853728781492, 0.12916298354558214, 0.12834045652280468, 0.12727282287878944, 0.15344394349085344, 0.15265372038118091, 0.15387863147224387, 0.15276163456121494, 0.15237241831632048, 0.15245513559876536, 0.15226499680931491, 0.15443852496197238, 0.15263680888996881, 0.15286062745033366, 0.21251675584055982, 0.18150122091726323, 0.18182990775733512, 0.18040818079706603, 0.18273338565632524, 0.18163467686831464, 0.18254811702359366, 0.18187433223629021, 0.17930265502864665, 0.18145439663114496, 0.18213179437242791, 0.20485131841099638, 0.20119982501504133, 0.23353863294130128, 0.23228893272046264, 0.20208115931894455, 0.15133338099756211, 0.1533769340121531, 0.15391457119932928, 0.15178401081092652, 0.19456448834115547, 0.19534523501331519, 0.19307368394046359, 0.19592083894051762, 0.18237470737700104, 0.18396869077091077, 0.26676817295039162, 0.26824252310427782, 0.26545174640642727, 0.26980830067085426, 0.27253771000800875, 0.27077303405802877, 0.14209631767000833, 0.1456654871525567, 0.14521704177556802, 0.14362973327618694, 0.14425118342808824, 0.14455374493706172, 0.14323297429136145, 0.14362969541711673, 0.14421419685979467, 0.14326124162382947, 0.14421361720983653, 0.27951662484764978, 0.27841871727755152, 0.27823992255144497, 0.28239237505119003, 0.27692999509342653, 0.2813440182629503, 0.13494806506899915, 0.13327769633790662, 0.16317111791491912, 0.1650207641313976, 0.1628430066137152, 0.16399617129148178, 0.19871036942053316, 0.2014923189692068, 0.19260887078760483, 0.19312096111759289, 0.19175673506227156, 0.1926519666858594, 0.19216184226944424, 0.19053778202546742, 0.19308110512503512, 0.19395600387841638, 0.192989114461838, 0.19116163247032558, 0.19044747201276313, 0.19169709495350784, 0.21835720701136863, 0.22064997788026419, 0.1281667909360508, 0.12870374855517785, 0.12740249089037961, 0.12863818756124837, 0.23945412217689044, 0.24341233982180444, 0.24348037754802138, 0.24090517135243519, 0.23962406050637217, 0.2424578169874457, 0.24368309966509435, 0.24224384826479256, 0.24441959713241143, 0.23798351015003644, 0.27624953299187305, 0.27547799340182716, 0.27374612327057801, 0.27590875739886045, 0.32695628708712821, 0.32547072589812803, 0.32744497584966287, 0.32915119485063271, 0.33258881985788968,  ...
# average of averages: 0.231238533197
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-215af3c36bcf> in <module>()
#      56
#      57         #################################################################
# ---> 58         X_2d_chunk, labels, sentences = clueweb_tsne_experiment()
#      59         plot_clueweb(X_2d_chunk, labels, sentences, title='t-SNE of textual instances of most common clueweb triples (6) (sampled)')
#      60         print 'done'
#
# NameError: name 'clueweb_tsne_experiment' is not defined
